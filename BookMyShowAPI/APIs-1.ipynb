# %%
import requests

# %%
data = requests.get("https://in.bookmyshow.com/api/explore/v1/discover/movies-bengaluru", 
    headers = {
    "accept": "application/json, text/plain, */*",
    "sec-ch-ua": "\".Not/A)Brand\";v=\"99\", \"Google Chrome\";v=\"103\", \"Chromium\";v=\"103\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sentry-trace": "19a9806b599e4b7ca8d7c4ef44fefc0a-b1c4d6f4f003222c-0",
    "x-app-code": "WEB",
    "x-bms-id": "1.86723830.1658656596938",
    "x-dc-token": "null",
    "x-latitude": "12.971599",
    "x-longitude": "77.594563",
    "x-platform-code": "DESKTOP-WEB"
});

# %%
data.json()
# Out:
# {'scrollId': 'bang:web:movies:production',
#  'pageId': '1',
#  'filterRoute': '/movies-bengaluru',
#  'meta': {'analytics': {'schema_version': '3.0',
#    'screen_name': 'movies_listing',
#    'event': 'gtm_allpages',
#    'event_name': 'movies_listing_viewed',
#    'event_type': 'screen_view',
#    'category': 'movies',
#    'product': 'movies',
#    'filtervalues': 'categories=movies',
#    'is_tvod': 'no'},
#   'scrollExpiry': 1200,
#   'ldSchema': {'itemListSchema': {'@context': 'http://schema.org',
#     '@type': 'ItemList',
#     'itemListElement': [{'@type': 'ListItem',
#       'image': 'https://assets-in.bmscdn.com/discovery-catalog/events/tr:w-400,h-600,bg-CCCCCC/et00075253-ccyjknqens-portrait.jpg',
#       'position': 1,
#       'url': 'https://in.bookmyshow.com/bengaluru/movies/shamshera/ET00075253',
#       'name': 'Shamshera'},
#      {'@type': 'ListItem',
# ...

# %%
regions=requests.get("https://in.bookmyshow.com/api/explore/v1/discover/regions")

# %%
regions.json()
# Out:
# {'BookMyShow': {'TopCities': [{'Alias': ['kalyan',
#      'mumbai: south & central',
#      'mumbai: western',
#      'thane',
#      'navi mumbai',
#      'ulhasnagar',
#      'mumbai'],
#     'AllowSales': 'Y',
#     'isOlaEnabled': 'N',
#     'Lat': '19.076',
#     'Long': '72.8777',
#     'RegionCallCenterNo': '',
#     'RegionCode': 'MUMBAI',
#     'RegionName': 'Mumbai',
#     'RegionSlug': 'mumbai',
#     'Seq': '1.0',
#     'HonourSubregionSlug': False,
#     'SubRegions': [{'AllowSales': 'Y',
#       'Lat': '19.12175',
#       'Long': '72.8504',
#       'Seq': '1.0',
#       'SubRegionCode': 'MWEST',
#       'SubRegionName': 'Mumbai: Western',
#       'SubRegionSlug': 'mumbai-western'},
#      {'AllowSales': 'Y',
#       'Lat': '19.0653',
#       'Long': '72.87942',
#       'Seq': '2.0',
#       'SubRegionCode': 'MCENT',
#       'SubRegionName': 'Mumbai: South & Central',
#       'SubRegionSlug': 'mumbai-south-central'},
#      {'AllowSales': 'Y',
#       'Lat': '19.1101',
# ...

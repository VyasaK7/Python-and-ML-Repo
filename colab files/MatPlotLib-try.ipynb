# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.2.2

# %%
import pandas
print(pandas.__version__)
# Out:
# 1.1.5

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([0,5])
y= np.array([0,10])

a=[0,577,23,21,333,1221,252]
b=[0,16550,23,21,333,227,222]

plt.plot(a,b,'P-r')
plt.show()

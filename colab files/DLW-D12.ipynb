# %% [markdown]
# # GAN Implementation

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError("GPU Device not Found")
print("Found GPU at: {}".format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
#device_name

# %%
import keras
from keras.layers import Dense, Conv2DTranspose, LeakyReLU, Reshape, BatchNormalization, Activation, Conv2D
from keras.models import Model, Sequential

# %%
# To define structure of generator model
#pass -- (will be used to signify a gap in code which i copied from the board(projection))
def generator_from_images():
  generator = Sequential()
  generator.add(Dense(256*4*4,input_shape=(100,)))
  generator.add(LeakyReLU())
  generator.add(Reshape((4,4,256)))
  #pass
  generator.add(Conv2DTranspose(128,kernel_size=3,strides=2,padding="same"))
  generator.add(LeakyReLU(alpha=0.2))
  #pass
  generator.add(Conv2DTranspose(128,kernel_size=3,strides=2,padding="same"))
  generator.add(LeakyReLU(alpha=0.2))
  #pass
  generator.add(Conv2DTranspose(128,kernel_size=3,strides=2,padding="same"))
  generator.add(LeakyReLU(alpha=0.2))
  #pass
  generator.add(Conv2D(3,kernel_size=3,padding="same",activation='tanh'))
  #pass
  return(generator)
#pass
model_generator = generator_from_images()
model_generator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 4096)              413696
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 4096)              0
#
#  reshape_1 (Reshape)         (None, 4, 4, 256)         0
#
#  conv2d_transpose (Conv2DTra  (None, 8, 8, 128)        295040
#  nspose)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 8, 128)         0
#
#  conv2d_transpose_1 (Conv2DT  (None, 16, 16, 128)      147584
#  ranspose)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 128)      147584
#  ranspose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  conv2d (Conv2D)             (None, 32, 32, 3)         3459
#
# =================================================================
# Total params: 1,007,363
# Trainable params: 1,007,363
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Checking if generative network works
# As the network is not trained yet, it should generate random images

import matplotlib.pyplot as plt
import numpy as np

def generate_input_data(n_samples):
  X = np.random.randn(100*n_samples)
  X = X.reshape(n_samples,100)
  return X

def create_fake_data(modelo_generador,n_samples):
  input = generate_input_data(n_samples)
  X = modelo_generadoe.predict(input)
  y = np.zeros((n_samples,1))
  return X,y 
n_samples=4

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# print('yo')

# %% [markdown]
# # Internship program

# %% [markdown]
# Sample program

# %%
j=0

# %%
print("j")
# Out:
# j

# %%
print(j)
# Out:
# 0

# %%
print('J' j)
# Out:
#   File "<ipython-input-13-565a4d8e794b>", line 1
#     print('J' j)
#               ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
x = [1,4,2,6,3]
y = [3,5,9,1,2]

# %%
x
# Out:
# [1, 4, 2, 6, 3]

# %%
y
# Out:
# [3, 5, 9, 1, 2]

# %%
plt.plot(x,y,marker='*',c='r')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Line Graph')
plt.show()

# %%
plt.pie(x,y)
# Out:
# ([<matplotlib.patches.Wedge at 0x1de75df02e8>,
# ...
#  [Text(4.021219649653245, 0.7998703202661259, ''),
#   Text(2.334368937427048, 5.635665148318849, ''),
#   Text(-7.14177848998413, 7.141778489984131, ''),
#   Text(-1.4849242404917502, -1.4849242404917498, ''),
#   Text(2.5775557981378903, -1.7222677223607668, '')])

# %%
plt.show(x,y)

# %%
plt.pie(x,y)
plt.show(x,y)

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1de75ba06d8>,
# ...
#  [Text(1.0788638084435536, 0.2145993542177411, ''),
#   Text(0.42095177560159885, 1.0162674857624154, ''),
#   Text(-0.7778174593052023, 0.7778174593052024, ''),
#   Text(-0.7778174593052025, -0.7778174593052023, ''),
#   Text(0.9146165735327998, -0.6111272563215624, '')])

# %%
plt.scatter(x,y)
plt.plot(x,y,c='y')

# %%
import numpy as np
a= np.arange(10)
b=np.random.randint(0,100000,10)
c= np.random.rand(10)
plt.scatter(a,b,c=c,s=b)

# %%
import matplotlib.pyplot as plt
people=['sathvik','vyasa','abheetha','Niha']
weight=[85,95,65,1000]
plt.bar(people,weight,width=1,color=['r','g','k','y'])
p=('People')
w=('Weight')
plt.xlabel(p)
plt.ylabel(w)
plt.title('My bar graph')
plt.show()
